# %%
import socket




def read_u():
    #a_u = int(c.recv(1024).decode())
    for i in range(5):
        print(c.recv(1024).decode())




        
        
            
    
def read_b():
    a = c.recv(1024).decode()
    a=int(a)
    
    
    for j in range(a):
        print(c.recv(1024).decode())
        for k in range(5):
            print(c.recv(1024).decode())
    

    
    


def write_b():
    n_i=input(c.recv(1024).decode())
    c.send(bytes(n_i,"utf-8"))
    for i in range(int(n_i)):
        print(c.recv(1024).decode())
        for j in range(5):
            a_i=input(c.recv(1024).decode())
            c.send(bytes(a_i,"utf-8"))
        a_i_1=input(c.recv(1024).decode())
        c.send(bytes(a_i_1,"utf-8"))
        a_i_2=input(c.recv(1024).decode())
        c.send(bytes(a_i_2,"utf-8"))
        
        
            
    
    















    
    
    




def check():
    a_i=input(c.recv(1024).decode())
    c.send(bytes(a_i,"utf-8"))
    i_c = int(c.recv(1024).decode())
    if(i_c==1):
        a_p=input(c.recv(1024).decode())
        c.send(bytes(a_p,"utf=8"))
        p_c = int(c.recv(1024).decode())
        if(p_c==1):
            control_access()
            
        else:
            print(c.recv(1024).decode())
            
        
        
    else:
        print(c.recv(1024).decode())
    
    
    
    
    
    
    
    
    
    
    
def control_access():
    c_a=input(c.recv(1024).decode())
    c.send(bytes(c_a,"utf-8"))
    control = int(c.recv(1024).decode())
    if(control == 1):
        read_u()
    elif(int(c_a) + 1 ==2):
        read_b()
    elif(control==3):
        write_b()
    elif(control==4):
        write_b()
        read_b()
    else:
        print(c.recv(1024).decode())
    
    
    
    
    
    
    









c = socket.socket()
c.connect(('localhost',9996))

a = input(c.recv(1024).decode())
c.send(bytes(a,"utf-8"))
if(int(a)==1 or int(a)==2):
    check()
else:
    print("No Role Found!!")
# Out:
# Select Role :
#  1->user
#  2->Boss
#  --->1
# Enter User ID : 1
# Enter Password : 111
# PRESS
# 	 1 -> Read
# 	 2-> Write
# 	 3 -> Write & Read
# 	 ----->1
# The details of user 1 are :
#
# 	userId->1
#
# 	firstName->Krish
# 	lastName->Lee
#
# 	phoneNumber->123456
#
# 	emailAddress->krish.lee@learningcontainer.com
